# %% [markdown]
# ## 1. Configuration and Imports

# %%
import json
import time
import numpy as np
from numpy.linalg import norm
from pydantic import BaseModel, Field
from ollama import chat, embeddings
from pathlib import Path

# ----- VARIABLES -----
model = "llama3:latest" #
ratio_queries = 1 # (0.1 = 10% of the dataset)
embedding_model = "mxbai-embed-large"
queries_type = "tool_only" 
# queries_type = "tool_param_expert_vocab"

# ----- FILE PATHS -----
script_folder = Path().absolute()
tools_list_path = script_folder.parent / 'input' / 'tools_list.json'
queries_list_path = script_folder.parent / 'input' / 'user_queries' / f'{queries_type}.json'
results_path = script_folder / 'output' / f'{model.replace(":", "-")}_{queries_type}.json'

# %% [markdown]
# ## 2. RAG Engine (Retrieval-Augmented Generation)

# %%
def get_vector(text): 
    """Fetches the embedding vector for a given text from Ollama."""
    response = embeddings(model=embedding_model, prompt=text)
    return response['embedding']

def precompute_tool_embeddings(tools_list):
    """Pre-calculates embeddings for all tools to save time during the routing phase."""
    print("Caching tool embeddings...")
    vecs = []
    for tool in tools_list:
        name = tool.get('name','')
        desc = tool.get('description',str(tool))
        tags = ", ".join(tool.get('tags',[]))
        text_to_embed = f"{name} : {desc}. Tags {tags}"
        vecs.append(get_vector(text_to_embed))
    return np.array(vecs)

def retrieve_top_tools(user_prompt, tools_list, tool_matrix, top_k=3):
    """Performs a fast vectorized cosine similarity search to find the top K tools."""

    query_vec = np.array(get_vector(user_prompt))
    # cosine similarity calculation using Numpy
    cosine_scores = np.dot(tool_matrix, query_vec) / (norm(tool_matrix, axis=1) * norm(query_vec))
    # Get the indices of the highest scores
    top_indices = np.argsort(cosine_scores)[::-1][:top_k]
    # Return both the score and the tool data
    return [(cosine_scores[i], tools_list[i]) for i in top_indices]

# %% [markdown]
# ## 3. LLM Router Agent

# %%
# ----- PYDANTIC SCHEMA -----
# This forces the LLM to output a strict JSON structure instead of conversational text
class RouteDecision(BaseModel):
    selected_tool: str = Field(description="The exact name of the tool. Return 'none' if no tool matches.")
    confidence: float = Field(description="Confidence level from 0.0 to 1.0")
    reasoning: str = Field(description="A short sentence explaining why this tool was chosen")

# ----- AGENT LOGIC -----
def agent_router(user_prompt: str, relevant_tools: list, model_name: str) -> RouteDecision:
    """Passes the filtered tools and user prompt to the LLM to make the final routing decision."""
    
    system_prompt = f"""You are a Router Agent expert in medical and dental imaging (CBCT, IOS, MRI).
    Your role is to analyze the user's request and select the most relevant tool from the FILTERED list below.
    If none of these {len(relevant_tools)} tools fit, return 'none'.

    Relevant Tools Subset:{json.dumps(relevant_tools, indent=2)}

    Carefully analyze the user's prompt, consider the available tools, and output your decision strictly matching the requested JSON schema.
    """
    
    try:
        response = chat(
            model=model_name,
            messages=[
                {'role': 'system', 'content': system_prompt},
                {'role': 'user', 'content': user_prompt},
            ],
            format=RouteDecision.model_json_schema(),
            options={"temperature": 0},
        )
        return RouteDecision.model_validate_json(response.message.content)
    except Exception as e:
        return RouteDecision(selected_tool="error", confidence=0.0, reasoning=f"Error: {str(e)}")

# %% [markdown]
# ## 4. Data Loading and Pre-computation

# %%
# ----- LOAD FILES -----
with open(tools_list_path, 'r', encoding='utf-8') as f:
    tools_list = json.load(f)

with open(queries_list_path, 'r', encoding='utf-8') as f:
    queries_list = json.load(f)

# ----- ONE-TIME EMBEDDING CACHE -----
t_start_setup = time.time()
tool_matrix = precompute_tool_embeddings(tools_list)
print(f"Embeddings matrix cached in {time.time() - t_start_setup:.2f}s")
# Out:
# Caching tool embeddings...
# Embeddings matrix cached in 1.48s

# %% [markdown]
# ## 5. Display Formatting Helpers

# %%
# ----- FORMATTING HELPER FUNCTIONS -----

def print_rag_block(index, total_queries, prompt, rag_icon, rag_results):
    """Handles the terminal output for the RAG search results."""
    print(f"\n{'='*65}")
    print(f"Prompt ({index}/{total_queries}) : '{prompt}'")
    print(f"{'-'*65}")
    print(f"I: RAG VECTOR SEARCH {rag_icon}")
    print(f"{'-'*65}")
    
    for i, (score, tool) in enumerate(rag_results, start=1):
        tool_name = tool.get('name', 'unknown_name')
        print(f"{i} Score: {score:.4f} tools: {tool_name}")
    print(f"{'-'*65}")


def print_llm_block(decision, expected_tool, llm_status_icon, latency):
    """Handles the terminal output for the LLM routing decision."""
    print("II: LLM ROUTER DECISION")
    print(f"{'-'*65}")  
    print(f"Tool chosen: {decision.selected_tool} {llm_status_icon} ")
    print(f"Expected   : {expected_tool}")
    print(f"Confidence : {decision.confidence * 100:.2f}%")
    print(f"Latency    : {latency:.2f} seconds")
    print(f"Reasoning  : {decision.reasoning}")

# %% [markdown]
# ## 6. Main Benchmark Loop

# %%
# ----- BENCHMARK INITIALIZATION -----
results_detail = []
llm_correct_count = 0
rag_correct_count = 0
total_time = 0.0

limit = max(1, int(len(queries_list) * ratio_queries))
queries_to_run = queries_list[:limit]
total_queries = len(queries_to_run)

# ----- MAIN EXECUTION LOOP -----
for index, (prompt, expected_tool) in enumerate(queries_to_run, start=1):

    t0 = time.time()
    
    # 1. Execute RAG
    rag_results = retrieve_top_tools(prompt, tools_list, tool_matrix, top_k=3)
    relevant_tools = [tool for score, tool in rag_results]
    
    # Check RAG success & extract tool names
    rag_tool_names = [t.get('name', 'unknown') for t in relevant_tools]
    rag_hit = expected_tool in rag_tool_names
    
    if rag_hit: rag_correct_count += 1
    rag_hit_sign = "✅" if rag_hit else "❌"
    rag_prediction_str = f"{', '.join(rag_tool_names)} {rag_hit_sign}"

    print_rag_block(index, total_queries, prompt, rag_hit_sign, rag_results)

    # 2. Execute LLM Router
    decision = agent_router(prompt, relevant_tools, model)
    t1 = time.time()
    
    latency = t1 - t0
    total_time += latency
        
    # Check LLM success & trigger print
    llm_hit = decision.selected_tool == expected_tool
    if llm_hit: llm_correct_count += 1
    llm_hit_sign = "✅" if llm_hit else "❌"

    print_llm_block(decision, expected_tool, llm_hit_sign, latency)

    # 3. Save iteration data
    results_detail.append({
        "prompt": prompt,
        "expected_tool": expected_tool,
        "rag_prediction": rag_prediction_str,
        "llm_prediction": f"{decision.selected_tool} {llm_hit_sign}",
        "Confidence": decision.confidence,
        "Latency": round(latency, 4),
        "reasoning": decision.reasoning
    })
# Out:
# =================================================================
# Prompt (1/140) : 'identify landmarks on CBCT scans'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.7913 tools: ali_cbct
# 2 Score: 0.7814 tools: semi_aso_cbct
# 3 Score: 0.7239 tools: ali_ios
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: ali_cbct ✅
# Expected   : ali_cbct
# Confidence : 100.00%
# Latency    : 3.35 seconds
# Reasoning  : The request to identify landmarks on CBCT scans matches the description of the 'ali_cbct' tool, which is specifically designed for automated anatomic landmark identification on cone-beam CT volumes.
#
# =================================================================
# Prompt (2/140) : 'automatic landmark detection on intraoral scans'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.8092 tools: ali_ios
# 2 Score: 0.7400 tools: ali_cbct
# 3 Score: 0.7260 tools: areg_ios
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: ali_ios ✅
# Expected   : ali_ios
# Confidence : 100.00%
# Latency    : 1.59 seconds
# Reasoning  : The request for automatic landmark detection on intraoral scans matches the description of the 'ali_ios' tool, which detects dental and anatomical landmarks on 3D surface meshes from intraoral scanners.
#
# =================================================================
# Prompt (3/140) : 'segment dental anatomical structures'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ❌
# -----------------------------------------------------------------
# 1 Score: 0.6834 tools: semi_aso_ios
# 2 Score: 0.6706 tools: semi_aso_cbct
# 3 Score: 0.6612 tools: batchdentalseg
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: batchdentalseg ❌
# Expected   : amasss_cli
# Confidence : 90.00%
# Latency    : 1.80 seconds
# Reasoning  : The request to segment dental anatomical structures suggests a need for automated processing and batch support, which is best served by the 'batchdentalseg' tool that uses pre-trained nnUNet deep learning models in 3D Slicer.
#
# =================================================================
# Prompt (4/140) : 'register baseline and follow-up CBCT images'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.7922 tools: areg_cbct
# 2 Score: 0.7703 tools: mri2cbct_reg
# 3 Score: 0.7432 tools: semi_aso_cbct
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: areg_cbct ✅
# Expected   : areg_cbct
# Confidence : 100.00%
# Latency    : 1.63 seconds
# Reasoning  : The user's request to register baseline and follow-up CBCT images matches the description of the 'areg_cbct' tool, which is designed for automatic registration of CBCT images for longitudinal studies.
#
# =================================================================
# Prompt (5/140) : 'register intraoral scan surfaces'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.7666 tools: areg_ios
# 2 Score: 0.7299 tools: ali_ios
# 3 Score: 0.7121 tools: flexreg
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: areg_ios ✅
# Expected   : areg_ios
# Confidence : 90.00%
# Latency    : 1.56 seconds
# Reasoning  : The request to register intraoral scan surfaces matches the description of 'areg_ios', which is specifically designed for automatic registration of Intraoral Scans using Iterative Closest Point (ICP).
#
# =================================================================
# Prompt (6/140) : 'crop region of interest from 3D volume'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.7991 tools: autocrop3d
# 2 Score: 0.6405 tools: mri2cbct_lr_crop
# 3 Score: 0.6310 tools: mri2cbct_tmj_crop
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: autocrop3d ✅
# Expected   : autocrop3d
# Confidence : 100.00%
# Latency    : 1.51 seconds
# Reasoning  : The user is asking to crop a region of interest from a 3D volume, which matches the description and tags of the 'autocrop3d' tool.
#
# =================================================================
# Prompt (7/140) : 'apply transformation matrix to scans'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.7456 tools: automatrix
# 2 Score: 0.6287 tools: mri2cbct_approx
# 3 Score: 0.6206 tools: pre_aso_cbct
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: automatrix ✅
# Expected   : automatrix
# Confidence : 100.00%
# Latency    : 1.16 seconds
# Reasoning  : The request is to apply a transformation matrix to scans, which matches the description of the 'automatrix' tool.
#
# =================================================================
# Prompt (8/140) : 'batch dental segmentation using nnUNet'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.8631 tools: batchdentalseg
# 2 Score: 0.7430 tools: amasss_cli
# 3 Score: 0.7070 tools: clic
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: batchdentalseg ✅
# Expected   : batchdentalseg
# Confidence : 100.00%
# Latency    : 1.44 seconds
# Reasoning  : The user's prompt explicitly requests 'batch dental segmentation' which matches the name and description of the 'batchdentalseg' tool.
#
# =================================================================
# Prompt (9/140) : 'CBCT segmentation with Mask R-CNN'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.8222 tools: clic
# 2 Score: 0.7627 tools: batchdentalseg
# 3 Score: 0.7349 tools: amasss_cli
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: clic ✅
# Expected   : clic
# Confidence : 100.00%
# Latency    : 1.24 seconds
# Reasoning  : The user is looking for CBCT segmentation using Mask-RCNN, which matches the description of the 'clic' tool.
#
# =================================================================
# Prompt (10/140) : 'shape analysis of dental surfaces'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.8160 tools: docshapeaxi
# 2 Score: 0.7286 tools: flexreg
# 3 Score: 0.7138 tools: ali_ios
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: docshapeaxi ✅
# Expected   : docshapeaxi
# Confidence : 100.00%
# Latency    : 1.91 seconds
# Reasoning  : The request for shape analysis of dental surfaces matches the description of the 'docshapeaxi' tool, which is specifically designed for statistical shape analysis and classification of 3D dental meshes with GradCAM visualization for interpretability and morphometric feature extraction.
#
# =================================================================
# Prompt (11/140) : 'flexible patch-based surface registration'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.7522 tools: flexreg
# 2 Score: 0.6475 tools: areg_ios
# 3 Score: 0.6365 tools: autocrop3d
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: flexreg ✅
# Expected   : flexreg
# Confidence : 100.00%
# Latency    : 1.49 seconds
# Reasoning  : The request for 'flexible patch-based surface registration' matches the description of the 'flexreg' tool, which is a flexible patch-based registration method for dental surfaces.
#
# =================================================================
# Prompt (12/140) : 'create medical data dashboard visualization'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.8408 tools: medx_dashboard
# 2 Score: 0.6247 tools: medx_summarize
# 3 Score: 0.5668 tools: docshapeaxi
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: medx_dashboard ✅
# Expected   : medx_dashboard
# Confidence : 100.00%
# Latency    : 1.40 seconds
# Reasoning  : The request to create a medical data dashboard visualization matches the description of MedX Dashboard, which is an interactive visualization tool for medical data and analysis summaries.
#
# =================================================================
# Prompt (13/140) : 'automatic medical text summarization'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.7403 tools: medx_summarize
# 2 Score: 0.5724 tools: medx_dashboard
# 3 Score: 0.5178 tools: autocrop3d
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: medx_summarize ✅
# Expected   : medx_summarize
# Confidence : 100.00%
# Latency    : 1.56 seconds
# Reasoning  : The request for automatic medical text summarization matches the description of MedX Summarize, which uses transformer-based NLP models to generate concise clinical summaries from patient notes.
#
# =================================================================
# Prompt (14/140) : 'MRI to CBCT approximation and preprocessing'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.8447 tools: mri2cbct_approx
# 2 Score: 0.7760 tools: mri2cbct_reg
# 3 Score: 0.7453 tools: mri2cbct_resample
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: mri2cbct_approx ✅
# Expected   : mri2cbct_approx
# Confidence : 100.00%
# Latency    : 1.49 seconds
# Reasoning  : The user's prompt specifically requests MRI to CBCT approximation and preprocessing, which is the primary function of the 'mri2cbct_approx' tool.
#
# =================================================================
# Prompt (15/140) : 'register MRI to CBCT images'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.8685 tools: mri2cbct_reg
# 2 Score: 0.8257 tools: mri2cbct_approx
# 3 Score: 0.7574 tools: areg_cbct
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: mri2cbct_reg ✅
# Expected   : mri2cbct_reg
# Confidence : 90.00%
# Latency    : 2.18 seconds
# Reasoning  : The user is asking to register MRI to CBCT images, which suggests a multimodal registration task. Based on the available tools, 'mri2cbct_reg' seems to be the most relevant tool for this task as it specifically handles MRI to CBCT image registration with intensity normalization.
#
# =================================================================
# Prompt (16/140) : 'crop left-right asymmetry analysis volumes'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.7696 tools: mri2cbct_lr_crop
# 2 Score: 0.6796 tools: autocrop3d
# 3 Score: 0.6293 tools: mri2cbct_tmj_crop
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: mri2cbct_lr_crop ✅
# Expected   : mri2cbct_lr_crop
# Confidence : 100.00%
# Latency    : 1.58 seconds
# Reasoning  : The user's prompt specifically requests to crop volumes for left-right asymmetry analysis, which is the primary function of the 'mri2cbct_lr_crop' tool.
#
# =================================================================
# Prompt (17/140) : 'orient and center MRI for standardization'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.8629 tools: mri2cbct_orient_center
# 2 Score: 0.7204 tools: mri2cbct_approx
# 3 Score: 0.7100 tools: mri2cbct_reg
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: mri2cbct_orient_center ✅
# Expected   : mri2cbct_orient_center
# Confidence : 100.00%
# Latency    : 2.06 seconds
# Reasoning  : The user's request to orient and center MRI scans for standardized positioning matches the description of the 'mri2cbct_orient_center' tool, which automatically reorients and centers MRI volumes to a canonical anatomical frame of reference for standardized analysis and comparison across subjects.
#
# =================================================================
# Prompt (18/140) : 'resample MRI and CBCT to uniform spacing'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.8629 tools: mri2cbct_resample
# 2 Score: 0.7764 tools: mri2cbct_approx
# 3 Score: 0.7632 tools: mri2cbct_reg
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: mri2cbct_resample ✅
# Expected   : mri2cbct_resample
# Confidence : 100.00%
# Latency    : 1.66 seconds
# Reasoning  : The user's request is to resample MRI and CBCT to uniform spacing, which matches the description of the 'mri2cbct_resample' tool.
#
# =================================================================
# Prompt (19/140) : 'temporomandibular joint region segmentation'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.8165 tools: mri2cbct_tmj_crop
# 2 Score: 0.6832 tools: batchdentalseg
# 3 Score: 0.6692 tools: amasss_cli
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: mri2cbct_tmj_crop ✅
# Expected   : mri2cbct_tmj_crop
# Confidence : 100.00%
# Latency    : 2.37 seconds
# Reasoning  : The user's prompt specifically requests temporomandibular joint (TMJ) region segmentation, which is a key feature of the 'mri2cbct_tmj_crop' tool. This tool automatically segments and extracts TMJ regions from MRI and CBCT scans using trained nnUNet models for focused TMJ analysis and disorder assessment.
#
# =================================================================
# Prompt (20/140) : 'preprocess CBCT for automatic segmentation'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.8299 tools: pre_aso_cbct
# 2 Score: 0.7796 tools: semi_aso_cbct
# 3 Score: 0.7628 tools: clic
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: pre_aso_cbct ✅
# Expected   : pre_aso_cbct
# Confidence : 100.00%
# Latency    : 1.55 seconds
# Reasoning  : The user is looking to preprocess CBCT scans for automatic segmentation, which aligns perfectly with the 'Preprocessing for Automatic Segmentation Orientation - CBCT' tool's description and tags.
#
# =================================================================
# Prompt (21/140) : 'preprocess intraoral scan for orientation'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.8018 tools: pre_aso_ios
# 2 Score: 0.7519 tools: pre_aso_cbct
# 3 Score: 0.7481 tools: ali_ios
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: pre_aso_ios ✅
# Expected   : pre_aso_ios
# Confidence : 100.00%
# Latency    : 1.70 seconds
# Reasoning  : The request to preprocess an intraoral scan for orientation matches the description of the 'pre_aso_ios' tool, which orients and preprocesses intraoral scan surfaces for standardized coordinate frames and tooth-specific segmentation and analysis.
#
# =================================================================
# Prompt (22/140) : 'semi-automatic CBCT orientation using landmarks'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.8358 tools: semi_aso_cbct
# 2 Score: 0.7780 tools: ali_cbct
# 3 Score: 0.7511 tools: pre_aso_cbct
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: semi_aso_cbct ✅
# Expected   : semi_aso_cbct
# Confidence : 100.00%
# Latency    : 1.47 seconds
# Reasoning  : The user's prompt specifically requests semi-automatic CBCT orientation using landmarks, which matches the description of the 'semi_aso_cbct' tool.
#
# =================================================================
# Prompt (23/140) : 'semi-automatic IOS orientation using landmarks'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.7129 tools: semi_aso_ios
# 2 Score: 0.6783 tools: ali_ios
# 3 Score: 0.6205 tools: pre_aso_ios
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: semi_aso_ios ✅
# Expected   : semi_aso_ios
# Confidence : 100.00%
# Latency    : 1.43 seconds
# Reasoning  : The user's prompt specifically requests semi-automatic IOS orientation using landmarks, which matches the description of the 'semi_aso_ios' tool.
#
# =================================================================
# Prompt (24/140) : 'detect landmark points on my CBCT'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.7765 tools: ali_cbct
# 2 Score: 0.7663 tools: semi_aso_cbct
# 3 Score: 0.6972 tools: pre_aso_cbct
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: ali_cbct ✅
# Expected   : ali_cbct
# Confidence : 100.00%
# Latency    : 1.57 seconds
# Reasoning  : The request to detect landmark points on a CBCT scan matches the description of the 'ali_cbct' tool, which is designed for automated anatomic landmarks identification on CBCT scans using AI agents.
#
# =================================================================
# Prompt (25/140) : 'find feature points in intraoral scans'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.7885 tools: ali_ios
# 2 Score: 0.7387 tools: areg_ios
# 3 Score: 0.7198 tools: ali_cbct
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: ali_ios ✅
# Expected   : ali_ios
# Confidence : 100.00%
# Latency    : 1.74 seconds
# Reasoning  : The request to find feature points in intraoral scans matches the description of the 'ali_ios' tool, which detects dental and anatomical landmarks on 3D surface meshes from intraoral scanners for orthodontic and prosthodontic analysis.
#
# =================================================================
# Prompt (26/140) : 'segment teeth from 3D scan'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ❌
# -----------------------------------------------------------------
# 1 Score: 0.7132 tools: docshapeaxi
# 2 Score: 0.7123 tools: ali_ios
# 3 Score: 0.7095 tools: semi_aso_ios
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: semi_aso_ios ❌
# Expected   : amasss_cli
# Confidence : 80.00%
# Latency    : 1.69 seconds
# Reasoning  : The request to segment teeth from a 3D scan suggests the need for semi-automatic segmentation and orientation of dental surfaces, which is the primary function of the 'Semi-Automatic Segmentation Orientation for IOS' tool.
#
# =================================================================
# Prompt (27/140) : 'align CBCT images before and after'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ❌
# -----------------------------------------------------------------
# 1 Score: 0.7330 tools: pre_aso_cbct
# 2 Score: 0.7157 tools: semi_aso_cbct
# 3 Score: 0.7091 tools: mri2cbct_approx
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: semi_aso_cbct ❌
# Expected   : areg_cbct
# Confidence : 80.00%
# Latency    : 1.59 seconds
# Reasoning  : The request to align CBCT images suggests a need for orientation correction and standardization, which is the primary function of the 'Semi-Automatic Segmentation Orientation for CBCT using landmarks' tool.
#
# =================================================================
# Prompt (28/140) : 'align two dental scan surfaces'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.6965 tools: areg_ios
# 2 Score: 0.6787 tools: semi_aso_cbct
# 3 Score: 0.6737 tools: flexreg
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: flexreg ❌
# Expected   : areg_ios
# Confidence : 90.00%
# Latency    : 1.66 seconds
# Reasoning  : The request to align two dental scan surfaces suggests a registration task that requires flexible deformation of one surface to match another. This is best achieved through patch-based deformable registration, which is the core functionality of the 'flexreg' tool.
#
# =================================================================
# Prompt (29/140) : 'extract area of interest from volume'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.6646 tools: autocrop3d
# 2 Score: 0.5877 tools: mri2cbct_lr_crop
# 3 Score: 0.5743 tools: mri2cbct_tmj_crop
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: autocrop3d ✅
# Expected   : autocrop3d
# Confidence : 100.00%
# Latency    : 1.39 seconds
# Reasoning  : The tool 'autocrop3d' is most relevant for extracting an area of interest from a volume as it allows for automatic cropping using ROI markers.
#
# =================================================================
# Prompt (30/140) : 'apply geometric transformation to scan'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.6645 tools: automatrix
# 2 Score: 0.6220 tools: mri2cbct_approx
# 3 Score: 0.6106 tools: pre_aso_cbct
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: automatrix ✅
# Expected   : automatrix
# Confidence : 100.00%
# Latency    : 1.36 seconds
# Reasoning  : The 'automatrix' tool is designed for automatic transformation matrix application to scans and surfaces, which aligns with the request to apply a geometric transformation to a scan.
#
# =================================================================
# Prompt (31/140) : 'segment multiple dental scans batch'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.7635 tools: batchdentalseg
# 2 Score: 0.6928 tools: areg_ios
# 3 Score: 0.6877 tools: semi_aso_cbct
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: batchdentalseg ✅
# Expected   : batchdentalseg
# Confidence : 100.00%
# Latency    : 1.57 seconds
# Reasoning  : The request to segment multiple dental scans in batch mode matches the description of the 'batchdentalseg' tool, which is designed for automated segmentation of dental structures from CBCT scans with batch processing support.
#
# =================================================================
# Prompt (32/140) : 'segment dental structures from CBCT'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.7692 tools: batchdentalseg
# 2 Score: 0.7561 tools: semi_aso_cbct
# 3 Score: 0.7457 tools: clic
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: batchdentalseg ❌
# Expected   : clic
# Confidence : 90.00%
# Latency    : 2.14 seconds
# Reasoning  : The user is asking to segment dental structures from CBCT, which matches the description of the 'batchdentalseg' tool. This tool uses pre-trained nnUNet deep learning models for automated segmentation of dental structures (teeth, bone, soft tissue) from CBCT scans with batch processing support.
#
# =================================================================
# Prompt (33/140) : 'analyze dental surface geometry'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.7867 tools: docshapeaxi
# 2 Score: 0.7179 tools: flexreg
# 3 Score: 0.7118 tools: ali_ios
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: docshapeaxi ✅
# Expected   : docshapeaxi
# Confidence : 90.00%
# Latency    : 1.35 seconds
# Reasoning  : The request to analyze dental surface geometry suggests a focus on shape analysis and morphometric feature extraction, which aligns with the capabilities of docshapeaxi.
#
# =================================================================
# Prompt (34/140) : 'register dental surfaces using patches'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.8225 tools: flexreg
# 2 Score: 0.7307 tools: docshapeaxi
# 3 Score: 0.7067 tools: areg_ios
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: flexreg ✅
# Expected   : flexreg
# Confidence : 100.00%
# Latency    : 1.50 seconds
# Reasoning  : The request to register dental surfaces using patches matches the description of the 'flexreg' tool, which uses patch-based deformable registration with butterfly and curve patch methods for precision tooth movement tracking.
#
# =================================================================
# Prompt (35/140) : 'build visualization dashboard for data'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.7277 tools: medx_dashboard
# 2 Score: 0.5208 tools: docshapeaxi
# 3 Score: 0.4968 tools: medx_summarize
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: medx_dashboard ✅
# Expected   : medx_dashboard
# Confidence : 100.00%
# Latency    : 1.66 seconds
# Reasoning  : The request to build a visualization dashboard for data matches the description of MedX Dashboard, which is an interactive visualization tool that generates HTML dashboards for visual exploration of clinical outcomes, measurements, and longitudinal study results.
#
# =================================================================
# Prompt (36/140) : 'summarize medical report text'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.7837 tools: medx_summarize
# 2 Score: 0.6599 tools: medx_dashboard
# 3 Score: 0.5101 tools: mri2cbct_orient_center
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: medx_summarize ✅
# Expected   : medx_summarize
# Confidence : 100.00%
# Latency    : 1.69 seconds
# Reasoning  : The request to summarize medical report text matches the description of MedX Summarize, which automatically generates concise clinical summaries from patient notes (PDF, DOCX, TXT) using transformer-based NLP models for quick clinical review.
#
# =================================================================
# Prompt (37/140) : 'approximate MRI to CBCT space'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.8109 tools: mri2cbct_approx
# 2 Score: 0.7684 tools: mri2cbct_reg
# 3 Score: 0.7351 tools: mri2cbct_resample
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: mri2cbct_approx ✅
# Expected   : mri2cbct_approx
# Confidence : 100.00%
# Latency    : 1.86 seconds
# Reasoning  : The user's prompt 'approximate MRI to CBCT space' matches the description of the 'mri2cbct_approx' tool, which preprocesses MRI and CBCT scans with intensity normalization and spatial reorientation for subsequent multimodal registration and fusion.
#
# =================================================================
# Prompt (38/140) : 'match MRI with CBCT coordinates'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.8181 tools: mri2cbct_approx
# 2 Score: 0.8114 tools: mri2cbct_reg
# 3 Score: 0.7655 tools: mri2cbct_resample
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: mri2cbct_reg ✅
# Expected   : mri2cbct_reg
# Confidence : 90.00%
# Latency    : 1.60 seconds
# Reasoning  : The request to match MRI with CBCT coordinates suggests a registration task, which is best handled by the 'mri2cbct_reg' tool that performs deformable registration with intensity normalization for joint imaging analysis.
#
# =================================================================
# Prompt (39/140) : 'extract left-right comparison region'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.6549 tools: mri2cbct_lr_crop
# 2 Score: 0.5790 tools: autocrop3d
# 3 Score: 0.5656 tools: mri2cbct_tmj_crop
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: mri2cbct_lr_crop ✅
# Expected   : mri2cbct_lr_crop
# Confidence : 100.00%
# Latency    : 1.79 seconds
# Reasoning  : The tool 'mri2cbct_lr_crop' is specifically designed for extracting left and right hemimandibular or hemimaxillary regions from registered MRI-CBCT pairs for bilateral morphometric comparison and asymmetry assessment.
#
# =================================================================
# Prompt (40/140) : 'center and orient MRI volume'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.8239 tools: mri2cbct_orient_center
# 2 Score: 0.6808 tools: mri2cbct_approx
# 3 Score: 0.6716 tools: mri2cbct_reg
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: mri2cbct_orient_center ✅
# Expected   : mri2cbct_orient_center
# Confidence : 100.00%
# Latency    : 2.02 seconds
# Reasoning  : The user's request to center and orient an MRI volume matches the description of the 'mri2cbct_orient_center' tool, which automatically reorients and centers MRI volumes to a canonical anatomical frame of reference for standardized analysis and comparison across subjects.
#
# =================================================================
# Prompt (41/140) : 'normalize MRI and CBCT resolution'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.8166 tools: mri2cbct_approx
# 2 Score: 0.8068 tools: mri2cbct_reg
# 3 Score: 0.7748 tools: mri2cbct_resample
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: mri2cbct_resample ✅
# Expected   : mri2cbct_resample
# Confidence : 100.00%
# Latency    : 1.44 seconds
# Reasoning  : The tool 'Resample MRI and CBCT to uniform spacing' seems to be the most relevant for normalizing the resolution of both MRI and CBCT images.
#
# =================================================================
# Prompt (42/140) : 'segment jaw joint area'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.7572 tools: mri2cbct_tmj_crop
# 2 Score: 0.6902 tools: semi_aso_ios
# 3 Score: 0.6798 tools: mri2cbct_lr_crop
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: mri2cbct_tmj_crop ✅
# Expected   : mri2cbct_tmj_crop
# Confidence : 90.00%
# Latency    : 1.89 seconds
# Reasoning  : The request to segment the jaw joint area is most closely matched by the 'mri2cbct_tmj_crop' tool, which automatically segments and extracts Temporomandibular Joint (TMJ) regions from MRI and CBCT scans.
#
# =================================================================
# Prompt (43/140) : 'prepare CBCT for automated analysis'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.7674 tools: pre_aso_cbct
# 2 Score: 0.7447 tools: semi_aso_cbct
# 3 Score: 0.7294 tools: ali_cbct
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: pre_aso_cbct ✅
# Expected   : pre_aso_cbct
# Confidence : 90.00%
# Latency    : 1.91 seconds
# Reasoning  : The 'pre_aso_cbct' tool is the most relevant choice to prepare CBCT scans for automated analysis as it provides standardized resampling, orientation correction, and field-of-view adjustment, which are essential steps in preparing CBCT data for subsequent automated segmentation pipelines.
#
# =================================================================
# Prompt (44/140) : 'process intraoral scan for orientation'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.7589 tools: pre_aso_ios
# 2 Score: 0.7387 tools: ali_ios
# 3 Score: 0.7247 tools: areg_ios
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: pre_aso_ios ✅
# Expected   : pre_aso_ios
# Confidence : 90.00%
# Latency    : 1.97 seconds
# Reasoning  : The request to process an intraoral scan for orientation suggests that the user wants to standardize the coordinate frame and prepare the surface for further analysis or segmentation. Based on this requirement, I recommend using 'pre_aso_ios' which is designed for preprocessing and orienting intraoral scan surfaces.
#
# =================================================================
# Prompt (45/140) : 'find CBCT orientation with landmarks'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.8245 tools: semi_aso_cbct
# 2 Score: 0.7825 tools: ali_cbct
# 3 Score: 0.7731 tools: pre_aso_cbct
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: semi_aso_cbct ✅
# Expected   : semi_aso_cbct
# Confidence : 100.00%
# Latency    : 1.52 seconds
# Reasoning  : The request specifically asks for finding CBCT orientation with landmarks, which is a key feature of the 'Semi-Automatic Segmentation Orientation for CBCT using landmarks' tool.
#
# =================================================================
# Prompt (46/140) : 'orient scan using anatomical points'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.7778 tools: mri2cbct_orient_center
# 2 Score: 0.7078 tools: semi_aso_cbct
# 3 Score: 0.6740 tools: semi_aso_ios
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: semi_aso_cbct ❌
# Expected   : semi_aso_ios
# Confidence : 90.00%
# Latency    : 1.82 seconds
# Reasoning  : The request to orient a scan using anatomical points matches the description of 'Semi-Automatic Segmentation Orientation for CBCT using landmarks', which uses manually-placed anatomical landmarks with ICP-based registration to orient and standardize CBCT scans.
#
# =================================================================
# Prompt (47/140) : 'where are the landmarks on this CBCT'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.7577 tools: ali_cbct
# 2 Score: 0.7424 tools: semi_aso_cbct
# 3 Score: 0.6841 tools: areg_cbct
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: ali_cbct ✅
# Expected   : ali_cbct
# Confidence : 80.00%
# Latency    : 1.26 seconds
# Reasoning  : The request to identify landmarks on a CBCT scan suggests that automated anatomic landmark identification using AI agents is the most relevant tool for this task.
#
# =================================================================
# Prompt (48/140) : 'how do i find anatomical points on scan'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.6767 tools: mri2cbct_orient_center
# 2 Score: 0.6619 tools: ali_cbct
# 3 Score: 0.6545 tools: ali_ios
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: ali_cbct ❌
# Expected   : ali_ios
# Confidence : 90.00%
# Latency    : 1.37 seconds
# Reasoning  : The request to find anatomical points on a scan suggests that the user is looking for automated landmark identification, which is a key feature of the ali_cbct tool.
#
# =================================================================
# Prompt (49/140) : 'can you segment my teeth structure'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ❌
# -----------------------------------------------------------------
# 1 Score: 0.6699 tools: semi_aso_ios
# 2 Score: 0.6681 tools: batchdentalseg
# 3 Score: 0.6659 tools: pre_aso_ios
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: batchdentalseg ❌
# Expected   : amasss_cli
# Confidence : 90.00%
# Latency    : 1.68 seconds
# Reasoning  : Based on the request to segment teeth structures, I recommend using 'batchdentalseg' as it is a tool specifically designed for automated segmentation of dental structures (teeth, bone, soft tissue) from CBCT scans.
#
# =================================================================
# Prompt (50/140) : 'i need to register my CBCT images'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.7378 tools: mri2cbct_reg
# 2 Score: 0.7282 tools: areg_cbct
# 3 Score: 0.6941 tools: semi_aso_cbct
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: areg_cbct ✅
# Expected   : areg_cbct
# Confidence : 100.00%
# Latency    : 1.20 seconds
# Reasoning  : The 'areg_cbct' tool is specifically designed for automatic registration of CBCT images, which matches your requirement.
#
# =================================================================
# Prompt (51/140) : 'how to align intraoral scans'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.7234 tools: ali_ios
# 2 Score: 0.7211 tools: areg_ios
# 3 Score: 0.7086 tools: pre_aso_ios
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: areg_ios ✅
# Expected   : areg_ios
# Confidence : 100.00%
# Latency    : 1.32 seconds
# Reasoning  : The 'Automatic Registration of Intraoral Scans using Iterative Closest Point (ICP)' tool is the most relevant for aligning intraoral scans.
#
# =================================================================
# Prompt (52/140) : 'extract region of interest'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.6571 tools: autocrop3d
# 2 Score: 0.6000 tools: mri2cbct_tmj_crop
# 3 Score: 0.5785 tools: mri2cbct_lr_crop
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: autocrop3d ✅
# Expected   : autocrop3d
# Confidence : 100.00%
# Latency    : 1.39 seconds
# Reasoning  : The request to extract a region of interest matches the description of autocrop3d, which is designed for automatic 3D region cropping using ROI markers.
#
# =================================================================
# Prompt (53/140) : 'transform scan coordinates'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.6110 tools: automatrix
# 2 Score: 0.5816 tools: mri2cbct_orient_center
# 3 Score: 0.5675 tools: pre_aso_cbct
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: automatrix ✅
# Expected   : automatrix
# Confidence : 100.00%
# Latency    : 1.65 seconds
# Reasoning  : The 'automatrix' tool is the most relevant for transforming scan coordinates as it applies pre-computed transformation matrices (rigid, affine, or deformable) to medical images and 3D surface meshes for standardized registration.
#
# =================================================================
# Prompt (54/140) : 'process many scans at one time'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.5738 tools: batchdentalseg
# 2 Score: 0.5687 tools: pre_aso_cbct
# 3 Score: 0.5639 tools: mri2cbct_orient_center
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: batchdentalseg ✅
# Expected   : batchdentalseg
# Confidence : 90.00%
# Latency    : 1.83 seconds
# Reasoning  : The request to process many scans at once suggests a batch processing task, which is a key feature of the 'batchdentalseg' tool. This tool allows for automated segmentation of dental structures from CBCT scans using pre-trained deep learning models with batch processing support.
#
# =================================================================
# Prompt (55/140) : 'segment cbct with deep learning'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.7709 tools: clic
# 2 Score: 0.7528 tools: batchdentalseg
# 3 Score: 0.7393 tools: amasss_cli
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: clic ✅
# Expected   : clic
# Confidence : 90.00%
# Latency    : 1.51 seconds
# Reasoning  : The user is looking to segment CBCT data using deep learning, which is a key feature of clic. Additionally, clic's instance segmentation capabilities make it suitable for dental and anatomical structure segmentation.
#
# =================================================================
# Prompt (56/140) : 'measure tooth shape differences'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.6915 tools: docshapeaxi
# 2 Score: 0.6679 tools: flexreg
# 3 Score: 0.6635 tools: ali_ios
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: docshapeaxi ✅
# Expected   : docshapeaxi
# ...
# Tool chosen: semi_aso_ios ❌
# Expected   : amasss_cli
# Confidence : 80.00%
# Latency    : 1.65 seconds
# Reasoning  : The request to segmentar estructuras dentales (segment dental structures) matches the description of the 'semi_aso_ios' tool, which uses semi-automatic segmentation and orientation for IOS using landmarks on dental surfaces.
#
# =================================================================
# Prompt (128/140) : 'registrar imagenes CBCT'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.7390 tools: mri2cbct_reg
# 2 Score: 0.7379 tools: areg_cbct
# 3 Score: 0.7300 tools: semi_aso_cbct
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: areg_cbct ✅
# Expected   : areg_cbct
# Confidence : 90.00%
# Latency    : 1.50 seconds
# Reasoning  : The request to 'registrar imagenes CBCT' suggests a need for automatic registration of CBCT images, which is the primary function of the 'areg_cbct' tool.
#
# =================================================================
# Prompt (129/140) : 'crear panel de datos'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.5801 tools: medx_dashboard
# 2 Score: 0.5101 tools: docshapeaxi
# 3 Score: 0.4990 tools: medx_summarize
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: medx_dashboard ✅
# Expected   : medx_dashboard
# Confidence : 80.00%
# Latency    : 1.40 seconds
# Reasoning  : The request to 'crear panel de datos' (create data panel) matches the description of MedX Dashboard as an interactive visualization tool for medical data and analysis summaries.
#
# =================================================================
# Prompt (130/140) : 'aproximacion MRI a CBCT'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.7871 tools: mri2cbct_approx
# 2 Score: 0.7718 tools: mri2cbct_reg
# 3 Score: 0.7258 tools: semi_aso_cbct
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: mri2cbct_approx ✅
# Expected   : mri2cbct_approx
# Confidence : 100.00%
# Latency    : 1.79 seconds
# Reasoning  : The user's prompt 'aproximacion MRI a CBCT' matches the description of the 'mri2cbct_approx' tool, which is specifically designed for MRI to CBCT approximation and preprocessing for multimodal registration.
#
# =================================================================
# Prompt (131/140) : 'I have a series of CBCT images from a patient taken at baseline and at a 6-month follow-up appointment, and I would like to register these images together to compare the changes over time. Can you help me align these two datasets so I can see exactly what has changed in the anatomical structures?'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.8025 tools: areg_cbct
# 2 Score: 0.7573 tools: semi_aso_cbct
# 3 Score: 0.7552 tools: mri2cbct_reg
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: areg_cbct ✅
# Expected   : areg_cbct
# Confidence : 90.00%
# Latency    : 1.94 seconds
# Reasoning  : The user is looking to register CBCT images for longitudinal studies, which matches the description of 'areg_cbct'. This tool is designed specifically for registering baseline and follow-up CBCT scans using deformable or rigid registration to track anatomical changes over time.
#
# =================================================================
# Prompt (132/140) : 'We have multiple dental patients with intraoral scans that we need to segment and analyze for automated detection of dental structures and anatomical landmarks. I need a batch processing solution that can handle dozens of scans at once and provide detailed segmentation results for each one.'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.8247 tools: batchdentalseg
# 2 Score: 0.7564 tools: ali_ios
# 3 Score: 0.7481 tools: areg_ios
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: batchdentalseg ✅
# Expected   : batchdentalseg
# Confidence : 90.00%
# Latency    : 1.88 seconds
# Reasoning  : The user is looking for a batch processing solution to segment dental structures from intraoral scans, which aligns perfectly with the 'Batch Dental Segmentation' tool's capabilities. This tool can handle multiple scans at once and provide detailed segmentation results for each one.
#
# =================================================================
# Prompt (133/140) : 'I'm working on a research project where I need to convert MRI images from the head and neck region into the CBCT coordinate space so that I can perform comparative analysis and overlay the datasets for surgical planning purposes. The goal is to create a unified representation that combines both modalities.'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.8468 tools: mri2cbct_approx
# 2 Score: 0.8335 tools: mri2cbct_reg
# 3 Score: 0.7804 tools: mri2cbct_resample
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: mri2cbct_reg ❌
# Expected   : mri2cbct_approx
# Confidence : 90.00%
# Latency    : 2.67 seconds
# Reasoning  : Based on your requirement to convert MRI images from the head and neck region into the CBCT coordinate space for comparative analysis and overlaying datasets for surgical planning purposes, I recommend using the 'mri2cbct_reg' tool. This tool is specifically designed for registering MRI volumes to CBCT reference frames with automatic intensity normalization, which aligns well with your goal of creating a unified representation that combines both modalities.
#
# =================================================================
# Prompt (134/140) : 'We need to analyze the temporomandibular joint region in detail from both MRI and CBCT imaging modalities. The scans need to be registered together, cropped to the specific joint area, and then analyzed for morphological changes and degenerative features that might indicate temporomandibular disorder.'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.8198 tools: mri2cbct_tmj_crop
# 2 Score: 0.7427 tools: mri2cbct_lr_crop
# 3 Score: 0.7130 tools: mri2cbct_reg
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: mri2cbct_tmj_crop ✅
# Expected   : mri2cbct_tmj_crop
# Confidence : 90.00%
# Latency    : 2.96 seconds
# Reasoning  : The user's request involves detailed analysis of the temporomandibular joint region from both MRI and CBCT modalities, which requires automatic segmentation and cropping of the TMJ region. The 'mri2cbct_tmj_crop' tool is the most relevant as it provides automatic Temporomandibular Joint (TMJ) region segmentation and cropping from MRI and CBCT scans using trained nnUNet models for focused TMJ analysis and disorder assessment.
#
# =================================================================
# Prompt (135/140) : 'I have a collection of 3D dental scan surfaces from multiple patients with different tooth alignments and morphologies. I need to perform a comprehensive shape analysis to compare geometric variations across the patient population and identify any outliers or unusual dental surface characteristics.'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.8422 tools: docshapeaxi
# 2 Score: 0.7505 tools: ali_ios
# 3 Score: 0.7457 tools: areg_ios
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: docshapeaxi ✅
# Expected   : docshapeaxi
# Confidence : 90.00%
# Latency    : 2.36 seconds
# Reasoning  : The user's request for comprehensive shape analysis of 3D dental surfaces with identification of outliers or unusual characteristics matches the description of 'Shape Analysis of dental surfaces using ShapeAXI' tool. This tool provides statistical shape analysis and classification of 3D dental meshes with GradCAM visualization for interpretability and morphometric feature extraction, which aligns well with the user's requirements.
#
# =================================================================
# Prompt (136/140) : 'Our clinic is implementing an automated workflow for dental image processing where we need to take raw CBCT scans, preprocess them for optimal segmentation quality, apply various transformations and registrations, and then generate a comprehensive medical dashboard that displays all the results and metrics for clinical review.'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ❌
# -----------------------------------------------------------------
# 1 Score: 0.7650 tools: pre_aso_cbct
# 2 Score: 0.7470 tools: areg_cbct
# 3 Score: 0.7324 tools: semi_aso_cbct
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: pre_aso_cbct ❌
# Expected   : medx_dashboard
# Confidence : 90.00%
# Latency    : 1.96 seconds
# Reasoning  : The user's request involves preprocessing CBCT scans for optimal segmentation quality, which aligns with the 'Preprocessing for Automatic Segmentation Orientation - CBCT' tool. This tool can standardize resampling, correct orientation, and adjust the field-of-view for subsequent automated segmentation pipelines.
#
# =================================================================
# Prompt (137/140) : 'I'm conducting a comparative study between MRI and CBCT imaging for jaw anatomy assessment. The protocol requires me to resample both modalities to identical spatial resolution, register them to the same coordinate system, and then extract specific anatomical regions for side-by-side asymmetry analysis between left and right sides of the mandible.'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ❌
# -----------------------------------------------------------------
# 1 Score: 0.8520 tools: mri2cbct_lr_crop
# 2 Score: 0.8010 tools: mri2cbct_reg
# 3 Score: 0.8004 tools: mri2cbct_approx
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: mri2cbct_lr_crop ❌
# Expected   : mri2cbct_resample
# Confidence : 90.00%
# Latency    : 3.03 seconds
# Reasoning  : The user's request involves resampling both modalities to identical spatial resolution, registering them to the same coordinate system, and extracting specific anatomical regions for side-by-side asymmetry analysis between left and right sides of the mandible. The 'mri2cbct_lr_crop' tool is the most relevant as it allows for MRI-CBCT registration with intensity normalization, followed by cropping the volumes to extract left and right hemimandibular or hemimaxillary regions for bilateral morphometric comparison and asymmetry assessment.
#
# =================================================================
# Prompt (138/140) : 'We need to set up a semi-automated preprocessing pipeline for intraoral scan data where the system can automatically detect anatomical landmarks, use them to determine the correct 3D orientation, and then standardize the position of each scan in a consistent way for downstream analysis and comparison with other scans in our database.'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ❌
# -----------------------------------------------------------------
# 1 Score: 0.7997 tools: ali_ios
# 2 Score: 0.7970 tools: pre_aso_ios
# 3 Score: 0.7753 tools: pre_aso_cbct
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: ali_ios ❌
# Expected   : semi_aso_ios
# Confidence : 90.00%
# Latency    : 1.84 seconds
# Reasoning  : The user's request matches the description of 'ali_ios' perfectly, as it involves automatic landmark identification (anatomical landmarks) for intraoral scan data, which is then used to determine the correct 3D orientation and standardize the position of each scan.
#
# =================================================================
# Prompt (139/140) : 'I have acquired high-resolution CBCT images of dental and maxillofacial structures, and I want to perform a detailed landmark-based analysis to identify key anatomical points that are important for orthodontic treatment planning. These landmarks will be used to assess skeletal relationships and guide clinical decision-making.'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.7997 tools: ali_cbct
# 2 Score: 0.7785 tools: semi_aso_cbct
# 3 Score: 0.7332 tools: pre_aso_cbct
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: ali_cbct ✅
# Expected   : ali_cbct
# Confidence : 90.00%
# Latency    : 2.70 seconds
# Reasoning  : The user's request for landmark-based analysis on CBCT images of dental and maxillofacial structures suggests the need for automated anatomic landmarks identification using AI agents. The 'ali_cbct' tool is the most relevant choice as it detects anatomical reference points on cone-beam CT volumes for precise dental and maxillofacial measurements and analysis, which aligns with the user's goal of identifying key anatomical points for orthodontic treatment planning.
#
# =================================================================
# Prompt (140/140) : 'We're implementing a multimodal imaging analysis system that requires flexible surface registration between dental casts, intraoral scans, and radiographic images. The system needs to handle different patch sizes and registration parameters to achieve optimal alignment while preserving fine anatomical details for surgical navigation applications.'
# -----------------------------------------------------------------
# I: RAG VECTOR SEARCH ✅
# -----------------------------------------------------------------
# 1 Score: 0.8067 tools: flexreg
# 2 Score: 0.7833 tools: areg_ios
# 3 Score: 0.7612 tools: docshapeaxi
# -----------------------------------------------------------------
# II: LLM ROUTER DECISION
# -----------------------------------------------------------------
# Tool chosen: flexreg ✅
# Expected   : flexreg
# Confidence : 90.00%
# Latency    : 1.84 seconds
# Reasoning  : The user's request involves flexible surface registration between dental casts, intraoral scans, and radiographic images, which aligns with the 'Flexible Patch-based Registration' tool's capabilities. The need for handling different patch sizes and registration parameters also matches the tool's description.

# %% [markdown]
# ## 7. Save and Global Results

# %%
# ----- FINAL METRICS CALCULATION -----
total_queries = len(queries_to_run)

# Calculate both accuracies
rag_accuracy = (rag_correct_count / total_queries) * 100 if total_queries > 0 else 0.0
llm_accuracy = (llm_correct_count / total_queries) * 100 if total_queries > 0 else 0.0
avg_time = (total_time / total_queries) if total_queries > 0 else 0.0

# Structure the final output JSON report
summary = {
    "model": model,
    "metrics": {
        "total_queries": total_queries,
        "rag_correct":rag_correct_count,
        "rag_accuracy": round(rag_accuracy, 2),
        "llm_correct":llm_correct_count,
        "llm_accuracy": round(llm_accuracy, 2),
        "average_latency": round(avg_time, 4),
        "total_time": round(total_time, 4),
    },
    "details": results_detail,
}

# ----- EXPORT RESULTS -----
results_path.parent.mkdir(parents=True, exist_ok=True)
with open(results_path, 'w', encoding='utf-8') as f:
    json.dump(summary, f, indent=4, ensure_ascii=False)

# ----- FINAL SUMMARY OUTPUT -----
print("\n BENCHMARK COMPLETED ")
print(f"RAG Accuracy (Top 3): {rag_accuracy:.2f}% ({rag_correct_count}/{total_queries})")
print(f"LLM Accuracy (Exact): {llm_accuracy:.2f}% ({llm_correct_count}/{total_queries})")
print(f"Average Time:         {avg_time:.2f} seconds per query")
print(f"Report saved to:      {results_path.name}")
# Out:
#  BENCHMARK COMPLETED
# RAG Accuracy (Top 3): 87.14% (122/140)
# LLM Accuracy (Exact): 72.86% (102/140)
# Average Time:         1.71 seconds per query
# Report saved to:      llama3-latest_tool_only.json
